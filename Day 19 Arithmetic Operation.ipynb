# %%
# Arithmatic Operation (calculation or sum operation) +,-,*,%,/,//,**

# %%
# Addition 
#Int
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
#Flot
a=10.5
b=20.3
c=a+b
print(c)
# Out:
# 30.8

# %%
#comolex
a=10+1j
b=20+2j
c=a+b
print(c)
# Out:
# (30+3j)

# %%
# Subtraction
#int
a=20
b=10
c=a-b
print(c)
# Out:
# 10

# %%
#flot
a=20.9
b=10.78
c=a-b
print(c)
# Out:
# 10.12

# %%
#Complex
a=20+2j
b=10+1j
c=a-b
print(c)
# Out:
# (10+1j)

# %%
# multiplication
a=20+2j
b=2
c=a*b
print(c)
# Out:
# (40+4j)

# %%
# Modulo (%) it shows division sum balance answer
a=5
b=2
c=a%b
print(c)
# Out:
# 1

# %%
a=10
b=2
c=a%b
print(c)
# Out:
# 0

# %%
# division
a=10
b=2
c=a/b
print(c)
# Out:
# 5.0

# %%
a=5
b=3
c=a/b
print(c)
# Out:
# 1.6666666666666667

# %%
# floor division (//) it shows the op with out the decimal value in division sum
a=5
b=3
c=a//b
print(c)
# Out:
# 1

# %%
# Exponention or power (**) x times 
a=2
b=3            # 2*2*2= 8 (out put)
c=a**b
print(c)
# Out:
# 8

# %%
a=5
b=4
c=a**b
print(c)
# Out:
# 625
