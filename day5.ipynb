# %%
# assigning avale to avariable

a=5
b=10
c=a+b
print(3)
# Out:
# 3

# %%
a=5
b=10
print(a)
print(b)
# Out:
# 5
# 10

# %%
#reduce the code line
a,b=5,10
print(a)
print(b)
# Out:
# 5
# 10

# %%
# same value for differend variables
x=5
y=5
print(x)
print(y)
# Out:
# 5
# 5

# %%
# reduce line
x=y=5
print(x)
print(y)
# Out:
# 5
# 5

# %%
# it should with alphapet or underscore (_)

age=10
print(age)
# Out:
# 10

# %%
_age=20
print(_age)
# Out:
# 20

# %%
first_value=100
print(first_value)
# Out:
# 100

# %%
# it should not start with numerical value
value1=25
print(value1)
# Out:
# 25

# %%
# it can be alphanemeric
num123=90
print(num123)
# Out:
# 90

# %%
# it is a case sensitive ( A and a )

a=25
A=15
print(A)
print(a)
# Out:
# 15
# 25

# %%
number=15000
Number=25000
print(number)
print(Number)
# Out:
# 15000
# 25000

# %%
# dont use python key words ( print, if, while, for, etc)
