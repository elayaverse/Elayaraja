# %%
# list entry

name="venmozhi"
age=6
hight=4.2
detail=["venmozhi",6,4.2]
detail
# Out:
# ['venmozhi', 6, 4.2]

# %%
#liat indexing

detail=["venmozhi",6,4.2]
detail[0]
# Out:
# 'venmozhi'

# %%
detail=["venmozhi",6,4.2]
detail[1]
# Out:
# 6

# %%
detail=["venmozhi",6,4.2]
detail[2]
# Out:
# 4.2

# %%
# indexing access

num=[10,20,30,[40,50],60]
print(num[0])
print(num[1])
print(num[2])
print(num[3][0])
print(num[3][1])
print(num[4])
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
# indexing modify

names=["venmozhi","revathi","nelavan"]
names[1]="kannammal"
names
# Out:
# ['venmozhi', 'kannammal', 'nelavan']

# %%
# indexing deletion

names=["venmozhi","nelavan","revathi","elaya"]
del names[3]
names
# Out:
# ['venmozhi', 'nelavan', 'revathi']

# %%
# list slicing

number=[10,20,30,40,50]
number[0:4]
# Out:
# [10, 20, 30, 40]

# %%
number=[10,20,30,40,50]
number[:4]
# Out:
# [10, 20, 30, 40]

# %%
number=[10,20,30,40,50]
number[0:]
# Out:
# [10, 20, 30, 40, 50]

# %%
# Slice method

food=["bread","jam","milk","juice"]
number=[10,20,30,40,50,60]
colors=["pink","black","red","yellow","green"]
s=slice(0,3)
print(food[s])
print(number[s])
print(colors[s])
# Out:
# ['bread', 'jam', 'milk']
# [10, 20, 30]
# ['pink', 'black', 'red']

# %%
#reversing the list [start:end:step]

num=[10,20,30,40,50,60,70,80,90]
num[::-1]
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 10]

# %%
num=[10,20,30,40,50,60,70,80,90]
num[-2::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
#slicing modify

num=[10,20,30,40,50,60,70,80,90]
num[0:4]=[1,2,3,4]
num
# Out:
# [1, 2, 3, 4, 50, 60, 70, 80, 90]

# %%
num=[10,20,30,40,50,60,70,80,90]
num[0:4]=[1,2,3,4,5,6,7,8]
print(num)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 50, 60, 70, 80, 90]

# %%
num=[10,20,30,40,50,60,70,80,90]
num[::2]=[1,1,1,1,1]
print(num)
# Out:
# [1, 20, 1, 40, 1, 60, 1, 80, 1]

# %%
#slicing deletion

num=[10,20,30,40,50,60,70,80,90]
del num[0:4]
num
# Out:
# [50, 60, 70, 80, 90]

# %%
num=[10,20,30,40,50,60,70,80,90] #slising 2 step 
del num[::2]
num
# Out:
# [20, 40, 60, 80]
