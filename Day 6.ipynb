# %%
# input functions

name=input("enter your name:")
age=input("enter your age:")
height=input("enter your height:")
# Out:
# enter your name: Venmozhi
# enter your age: 6
# enter your height: 4.3

# %%
print(name)
print(age)
print(height)
# Out:
# Venmozhi
# 6
# 4.3

# %%
# check type of function and correct it

type(name)
# Out:
# str

# %%
# change age type and correct 

type(age)

# the age type is wrong it should store in int type
# Out:
# str

# %%
# data type converstion STR to INT

age=int(input("enter your age:"))
# Out:
# enter your age: 6

# %%
type(age)
# Out:
# int

# %%
#add age
age=age+5

# %%
print(age)
# Out:
# 11

# %%
# check height data type
type(height)
# Out:
# str

# %%
# data type converstion STR to INT
height=float(input("enter your height"))
# Out:
# enter your height 4.3

# %%
type(height)
# Out:
# float

# %%
print(name)
print(age)
print(height)
# Out:
# Venmozhi
# 11
# 4.3

# %%
print(name,age,height)
# Out:
# Venmozhi 11 4.3

# %%
print("your name is:",name)
print("your age is:",age)
print("your height is:",height)
# Out:
# your name is: Venmozhi
# your age is: 11
# your height is: 4.3

# %%
print("your name is\t:\t",name)
print("your age is\t:\t",age)
print("your height is\t:\t",height)
# Out:
# your name is	:	 Venmozhi
# your age is	:	 11
# your height is	:	 4.3

# %%
print(f"your name is {name} your age is {age} your height is {height}")
# Out:
# your name is Venmozhi your age is 11 your height is 4.3

# %%
print(f"your name is\t :\t{name}\nyour age is\t :\t{age}\nyour height is\t :\t{height}")
# Out:
# your name is	 :	Venmozhi
# your age is	 :	11
# your height is	 :	4.3
