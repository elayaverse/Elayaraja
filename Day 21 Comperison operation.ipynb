# %% [markdown]
# # comperation operation (==, !=, <, >, <=, >=)
#
# # it Use compaer two value or variables

# %%
# equales to (==)

a=10
b=10
print(a==b)
# Out:
# True

# %%
a=10
b=20
print(a==b)
# Out:
# False

# %%
a=20
b=20
a==b
# Out:
# True

# %%
# Not equales to (!=)
a=10
b=10
print(a!=b)
# Out:
# False

# %%
a=10
b=15
print(a!=b)
# Out:
# True

# %%
# Greater than(>)
a=10
b=9
print(a>b)
# Out:
# True

# %%
a=10
b=10
print(a>b)
# Out:
# False

# %%
# lesser than(<)
a=10
b=9
print(a<b)
# Out:
# False

# %%
a=10
b=19
print(a<b)
# Out:
# True

# %%
# Greater than or equal to (>=)
a=10
b=9
print(a>=b)
# Out:
# True

# %%
a=10
b=90
print(a>=b)
# Out:
# False

# %%
a=10
b=10
print(a>=b)
# Out:
# True

# %%
# lesser than or equal to(<=)
a=10
b=9
print(a<=b)
# Out:
# False

# %%
a=10
b=90
print(a<=b)
# Out:
# True

# %%
a=10
b=10
print(a<=b)
# Out:
# True

# %%
a=[10,20]
b=[10,20]
print(a==b)
# Out:
# True

# %%
a=[10,20,"hai"]
b=[10,20]
print(a==b)
# Out:
# False
