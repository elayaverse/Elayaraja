# %%
                              # list Basic operation 
 # lenght 
l1=[1,2,3,"hello"]
print(len(l1))
# Out:
# 4

# %%
l2=[1,2,3,["hello"]]
print(len(l2))
# Out:
# 4

# %%
l3=[1,2,3,["hello",10]]
print(len(l3))
# Out:
# 4

# %%
#concatenation  (join)

l1=[1,2,3]
l2=[4,5,6]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# repetition (again)
l1=[1,2,3]
print(l1*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# membership operator

ll=[1,2,3,4]
3 in l1
# Out:
# True

# %%
ll=[1,2,3,4]
6 in l1
# Out:
# False

# %%
                                # list buit in methods 
#find buit in l1.

l1[]
l1.             #tapkey

# %%
#append() extend()- in string value
# 1 append()

l1=["blue","yellow","black"]
l1.append("red")
print(l1)
# Out:
# ['blue', 'yellow', 'black', 'red']

# %%
# 2 extend()
l2=["blue","yellow","black"]
l2.extend("red")
print(l2)
# Out:
# ['blue', 'yellow', 'black', 'r', 'e', 'd']

# %%
#append() extend()- in numric value
# 1 append()

l1=["blue","yellow","black"]
l1.append("20")
print(l1)
# Out:
# ['blue', 'yellow', 'black', '20']

# %%
# 2 extend()
l2=["blue","yellow","black"]
l2.extend("20")
print(l2)
# Out:
# ['blue', 'yellow', 'black', '2', '0']

# %%
#append() extend()- string list
# 1 append()

a=["red","black"]
b=["pink","yellow"]
a.append(b)
print(a)
# Out:
# ['red', 'black', ['pink', 'yellow']]

# %%
#append() extend()- string list
# 2 extend()

a=["red","black"]
b=["pink","yellow"]
a.extend(b)
print(a)
# Out:
# ['red', 'black', 'pink', 'yellow']

# %%
#append() extend()- string list
# 1 append()

a=[1,2,3,4]
b=[5,6,7]
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, [5, 6, 7]]

# %%
#append() extend()- string list
# 2 extend ()

a=[1,2,3,4]
b=[5,6,7]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#insert()

l1=["blue","yellow","red"]
l1.insert(2,"black")
print(l1)
# Out:
# ['blue', 'yellow', 'black', 'red']

# %%
#pop()

l1=["blue","yellow","red"]
l1.pop()
print(l1)
# Out:
# ['blue', 'yellow']

# %%
l1=["blue","yellow","red"]
l1.pop(1)
print(l1)
# Out:
# ['blue', 'red']

# %%
#remove()
l1=["red","black","pink"]
l1.remove("pink")
print(l1)
# Out:
# ['red', 'black']

# %%
l2=["red","pink","black","pink"]
l2.remove("pink")
print(l2)
# Out:
# ['red', 'black', 'pink']

# %%
#clear()

l1=["red","pink","black","pink"]
l1.clear()
print(l1)
# Out:
# []

# %%
#del()

l1=["red","pink","black","pink"]
del l1
print(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       1 #del()
#       2
#       3 l1=["red","pink","black","pink"]
#       4 del l1
# ----> 5 print(l1)
#
# NameError: name 'l1' is not defined

# %%
#index ()

l1=["black","red","pink","yellow"]
l1.index("red")
# Out:
# 1

# %%
#count ()

l1=["black","red","pink","red"]
l1.count("red")
# Out:
# 2

# %%
#copy ()

l1=["black","red","pink","red"]
l2=l1.copy()
print(l2)
# Out:
# ['black', 'red', 'pink', 'red']

# %%
#sort ()

l1=["black","red","pink","red"]
l1.sort()
print(l1)
# Out:
# ['black', 'pink', 'red', 'red']

# %%
#reverse ()

l1=["black","red","pink","red"]
l1.reverse()
print(l1)
# Out:
# ['red', 'pink', 'red', 'black']
