# %%
#Boolean in python 
# it use to find true or false, and it is should capial letter for its first letter

# %%
# Assigning boolean value
a=True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
a=False
print(a)
print(type(a))
# Out:
# False
# <class 'bool'>

# %%
a=12
b=10
c=a>b
print(c)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
# basic operation boolean   Value is True=1 false=0
print(True+True)
# Out:
# 2

# %%
print(True+False)
# Out:
# 1

# %%
print(False+False)
# Out:
# 0

# %%
# passing int-bool
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(10)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
#flot - bool
bool(8.526)
# Out:
# True

# %%
s=(8254)
bool(s)
# Out:
# True

# %%
#string bool
bool("hello")
# Out:
# True

# %%
a=("king")
bool(a)
# Out:
# True

# %%
# list - bool
bool(["raja"])
# Out:
# True

# %%
# Tuple - bool
bool(("nilavan"))
# Out:
# True

# %%
# set - bool
bool({"nilavan",5,8})
# Out:
# True

# %%
# dictionary - bool
bool({"nilavan":5})
# Out:
# True

# %%
#bool false - empty bracket means it shows false
bool("")
# Out:
# False

# %%
# None data type ( it is not assign any value to code)
a=None
type(a)
# Out:
# NoneType

# %%
a=None #(it shows menory address of value)
id(a)
# Out:
# 140727575067232
