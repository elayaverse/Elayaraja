# %%
# capitalize ()(Capitalize Its First word only)

a="hey buddies"
print(a.capitalize())
# Out:
# Hey buddies

# %%
# count() it has count word or letters

b="welcome to rock"
print(b.count("welcome"))
# Out:
# 1

# %%
b="welcome to rock"
print(b.count("o"))
# Out:
# 3

# %%
b="welcome to rock"
print(b.count("o",0,10))
# Out:
# 2

# %%
# islower()

c="PYThon for TODDlers"
d="pythan for toddlers"
print(c.islower())
print(d.islower())
# Out:
# False
# True

# %%
# Lower()

c="PYThon for TODDlers"
d="pythan for toddlers"
print(c.lower())
print(d.lower())
# Out:
# python for toddlers
# pythan for toddlers

# %%
#isupper()

c="PYThon for TODDlers"
d="PYTHON FOR TODDLERS"
print(c.isupper())
print(d.isupper())
# Out:
# False
# True

# %%
#upper()
c="PYThon for TODDlers"
d="PYTHON FOR TODDLERS"
print(c.upper())
print(d.upper())
# Out:
# PYTHON FOR TODDLERS
# PYTHON FOR TODDLERS

# %%
# swapcase()

f="PYTHON FOR TODDLERS"
print(f.swapcase())
# Out:
# python for toddlers

# %%
# istitle()

g="welcome to rock"
print(g.istitle())
# Out:
# False

# %%
# title()

g="welcome to rock"
print(g.title())
# Out:
# Welcome To Rock

# %%
# startswith()

v="hey how are you"
print(v.startswith("hey"))
print(v.startswith("Y"))
# Out:
# True
# False

# %%
# endswirg ()

v="hey how are you??"
print(v.endswith("hey"))
print(v.endswith("??"))
# Out:
# False
# True

# %%
# isnumeric ()

ray="123"
print(ray.isnumeric())
# Out:
# True

# %%
ray="123ela"
print(ray.isnumeric())
# Out:
# False

# %%
# isalpha()

ap="hello"
print(ap.isalpha())
# Out:
# True

# %%
ap="hello25"
print(ap.isalpha())
# Out:
# False

# %%
# isalnum()  Find its with alphabets and numbers

k="rock12"
print(k.isalnum())
# Out:
# True

# %%
k="rock"
print(k.isalnum())
# Out:
# True

# %%
k="12"
print(k.isalnum())
# Out:
# True

# %%
# find()

x="welcome to rock"
print(x.find("to"))
# Out:
# 8

# %%
x="welcome to rock"
print(x.find("to0"))
# Out:
# -1

# %%
# index()

x="welcome to rock"
print(x.index("to"))
# Out:
# 8

# %%
# in index() this is shows error
x="welcome to rock"
print(x.index("to0"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 x="welcome to rock"
# ----> 2 print(x.index("to0"))
#
# ValueError: substring not found

# %%
# replace ()

z="i love dogs"
print(z.replace("love","like"))
# Out:
# i like dogs

# %%
z="i love dogs, i love flower, i love birds"
print(z.replace("i","we",2))
# Out:
# we love dogs, we love flower, i love birds

# %%
z="i love dogs"
print(z.replace("love","like"))

# %%
# strip()

w="@#$rock@$$"
print(w.strip("@$$#$"))
# Out:
# rock

# %%
w="@$$rock@$$"
print(w.lstrip("@$$"))
# Out:
# rock@$$

# %%
w="@$$rock@$$"
print(w.rstrip("@$$"))
# Out:
# @$$rock

# %%
# ljust (), rjust(), center()

j="rock"
print(j.ljust(10,'$'))
# Out:
# rock$$$$$$

# %%
j="rock"
print(j.rjust(10,'$'))
# Out:
# $$$$$$rock

# %%
j="rock"
print(j.center(10,'$'))
# Out:
# $$$rock$$$
