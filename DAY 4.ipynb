# %%
print('hey buddies')
# Out:
# hey buddies

# %%
print("you're here to learn python")
# Out:
# you're here to learn python

# %%
#double quotes in stattement
print('"you are here to learn python"')
# Out:
# "you are here to learn python"

# %%
#use double & single quotes in same statement use \ back slash
print('"you\'re here to learn python"')
# Out:
# "you're here to learn python"

# %%
#write the over in single code

print("welcome\nto\nrock")
# Out:
# welcome
# to
# rock

# %%
#output with tap space

print("Name\t:\tElaya\nGendre\t:\tMale")
# Out:
# Name	:	Elaya
# Gendre	:	Male

# %%
#seperate the word with space ,

print("happy","learning")

print("happy","learning",sep="_")

print("happy","learning",sep=" + ")

print("happy","learning",sep="")
# Out:
# happy learning
# happy_learning
# happy + learning
# happylearning

# %%
#end perameter

print("welcome",end="")
print("to",end="")
print("rock",end=".")
# Out:
# welcometorock.

# %%
#end perameter 2

print("welcome",end=" ")
print("to",end=" ")
print("rock",end=".")
# Out:
# welcome to rock.

# %%
#start new line with space and * sym

print("welcome to rock",end="\n\t*")
print("Python Series",end="\n\t*")
print("tips $ tricks",end=".")
# Out:
# welcome to rock
# 	*Python Series
# 	*tips $ tricks.
